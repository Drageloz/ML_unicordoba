# %% [markdown]
# #Paginas de importancia

# %% [markdown]
# Las siguientes páginas contienen el código fuente d elas librerias que utilizaremos, así como documentación de su uso
#
#         #https://github.com/rdkit/rdkit/tree/master/rdkit
#         #http://rdkit.org/docs/cppapi/namespaceRDKit.html
#
#
# LAs siguientes páginas nos ayudan como bibliografía para el estudio del tema en cuestión
#
#         #https://www.cell.com/joule/fulltext/S2542-4351(17)30130-7?_returnURL=https%3A%2F%2Flinkinghub.elsevier.com%2Fretrieve%2Fpii%2FS2542435117301307%3Fshowall%3Dtrue
#         #https://www.cell.com/cms/10.1016/j.joule.2017.10.006/attachment/f073fbea-3136-4be4-bf44-e31031e73c19/mmc1.pdf
#         #file:///C:/Users/andre/AppData/Local/Temp/Rar$DIa7480.46608/Ira%20N.%20Levine-Quantum%20Chemistry-Pearson%20(2013).pdf
#         #https://books.google.com.co/books?id=xkzquS1LRGIC&pg=PA13&lpg=PA13&dq=stretching+energy+molecules&source=bl&ots=ykWeCmiurs&sig=ACfU3U3dc7aWoyfxwQ1L7Z58R-XVWFPEYA&hl=es-419&sa=X&ved=2ahUKEwjhxund85DqAhVrQTABHavLAgAQ6AEwCHoECAkQAQ#v=onepage&q=stretching%20energy%20molecules&f=false
#         #http://bidd.nus.edu.sg/group/teach/compsci/compchem3.htm
#         #https://chem.libretexts.org/Bookshelves/Physical_and_Theoretical_Chemistry_Textbook_Maps/Supplemental_Modules_(Physical_and_Theoretical_Chemistry)/Chemical_Bonding/Fundamentals_of_Chemical_Bonding/Bond_Order_and_Lengths
#         #https://chem.libretexts.org/Bookshelves/Ancillary_Materials/Reference/Reference_Tables/Atomic_and_Molecular_Properties/A3%3A_Covalent_Radii
#         #https://cactus.nci.nih.gov/presentations/meeting-08-2011/Fri_Aft_Greg_Landrum_RDKit-PostgreSQL.pdf
#         #http://lammpstube.com/wp-content/uploads/2019/10/UFF-2.
#         #https://mro.massey.ac.nz/bitstream/handle/10179/12987/02_whole.pdf?sequence=2&isAllowed=y
#         #https://arxiv.org/pdf/1507.07343.pdf
#         #file:///C:/Users/andre/Downloads/FundamentalsofRenewableEnergyProcesses.pdf
#         #http://asteeves.github.io/blog/2015/01/12/conformations-in-rdkit/
#         #https://www.chem.uci.edu/~jsnowick/groupweb/Maestro/molecular_mechanics.pdf
#
#
# Las siguientes páginas ayudan a comprobar que se aplicac correctamente el método MMFF para hallar la energía mínima:
#
# La primera posee la información del structure name que nos entregan en la tabla de la tercera en el apendice A, mientras que la segunda nos entrega información del smile de dicha molécula
#
#         #https://www.ccdc.cam.ac.uk/structures/
#         #https://cactus.nci.nih.gov/chemical/structure/2,2'-Bipyridinium%20dichloride/smiles
#         #https://digitalcommons.unl.edu/cgi/viewcontent.cgi?article=1047&context=chemistrydiss
#
#
# Artículo sobre DFT and machine learning with lowest error
#
#         #https://arxiv.org/pdf/1702.05532.pdf
#
#         #Fin

# %% [markdown]
# #cargar Dependencias

# %% [markdown]
# ##Carga de Drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# ##instalación de paquetes Pylatex

# %%
! sudo apt-get install texlive-latex-recommended 
! sudo apt install texlive-latex-extra
! sudo apt install dvipng
# !pip install pylatex;
# !pip install pylatex[matrices]
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6
#   libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13
#   lmodern poppler-data t1utils tex-common texlive-base texlive-binaries
#   texlive-latex-base
# Suggested packages:
#   fonts-noto poppler-utils ghostscript fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum debhelper gv
#   | postscript-viewer perl-tk xpdf-reader | pdf-viewer texlive-latex-base-doc
#   texlive-latex-recommended-doc texlive-pstricks
# ...

# %% [markdown]
# ##intalación de paquetes necesarios: rdkit

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit

import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-08-26 12:40:51--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2020-08-26 12:40:51--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88867207 (85M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.3-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  84.75M   208MB/s    in 0.4s
#
# ...

# %% [markdown]
# ##Carga de librerías

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %%
from rdkit import Chem
from rdkit.Chem import DataStructs
from rdkit.Chem import AllChem
from rdkit.Chem import RDConfig
from rdkit import rdBase
from rdkit.Chem.Draw import IPythonConsole, ShowMol
from rdkit.Chem import PyMol
from rdkit.Chem import Draw
from __future__ import print_function
from IPython.display import SVG

from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
import copy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-eb41876828c5> in <module>()
# ----> 1 from rdkit import Chem
#       2 from rdkit.Chem import DataStructs
#       3 from rdkit.Chem import AllChem
#       4 from rdkit.Chem import RDConfig
#       5 from rdkit import rdBase
#
# ModuleNotFoundError: No module named 'rdkit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from pylatex import Document, Section, Subsection, Tabular, Math, TikZ, Axis, \
    Plot, Figure, Matrix, Alignat, Package, Command   
from pylatex.utils import italic, NoEscape

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# #LaTex File

# %%
data_article = pd.read_excel('/content/drive/My Drive/proyectoSolarCells/docs/textArticle.xlsx')

#LLena el documento con la información de texto, fórmulas, imagenes, etc.
def fill_document(doc):
    secuenceProcessArticle_image = os.path.join("/content/drive/My Drive/proyectoSolarCells/img/", 'secuenciaArticleNo-fullerene.png')
    bondStretchingEnergy_image = os.path.join("/content/drive/My Drive/proyectoSolarCells/img/", 'Bond_stretching_energy.png')
    angleBendingEnergy_image = os.path.join("/content/drive/My Drive/proyectoSolarCells/img/", 'angleBending.png')

#######################    DESCRIPCIÓN DEL PROCESO   ###########################
    with doc.create(Section('Descripción del proceso')):
      doc.append(data_article['Texto'][0])
      with doc.create(Figure(position='h!')) as secuence_pic:
              secuence_pic.add_image(secuenceProcessArticle_image, width='180px')
              secuence_pic.add_caption('Secuencia del artículo')
      doc.append(data_article['Texto'][1])
      #energias =['{tot}' ,'{str}', '{bend}', '{oop}', '{tors}', '{cross}', '{vdw}', '{es}']
      doc.append(NoEscape(r'{}'.format(data_article['formula'][0])))
      doc.append(NoEscape(r'{}'.format(data_article['Texto'][2])))
      doc.append(NoEscape(r'{}'.format(data_article['formula'][1])))
      #doc.append(NoEscape(r' '))
      doc.append(NoEscape(r'{}'.format(data_article['Texto'][3])))
      with doc.create(Figure(position='H')) as secuence_pic:
              secuence_pic.add_image(bondStretchingEnergy_image, width='160px')
              secuence_pic.add_caption('Bond Energy')
      doc.append(NoEscape(r'{}'.format(data_article['Texto'][4])))
      doc.append(NoEscape(r'{}'.format(data_article['formula'][2])))
      with doc.create(Figure(position='H')) as secuence_pic:
                secuence_pic.add_image(angleBendingEnergy_image, width='180px')
                secuence_pic.add_caption('Bond Energy')





#######################    SECCION PREGUNTAS   #################################
    with doc.create(Section('Preguntas')):
       for pregunta in data_article['preguntas']:
         if pregunta == pregunta:   
           doc.append(pregunta)


if __name__ == '__main__':
    doc = Document()
    doc.packages.add(Package('amsmath'))
    doc.packages.add(Package('amssymb'))
    doc.packages.add(Package('nccmath'))
    doc.packages.add(Package('hyperref'))
    doc.preamble.append(NoEscape(r'''\hypersetup{
    colorlinks=true,
    linkcolor=blue,
    filecolor=magenta,      
    urlcolor=cyan,
    }'''))
    doc.packages.add(Package('float'))


    doc.packages.add(Package('grffile', options=['encoding', 'filenameencoding=utf8']))
    doc.preamble.append(Command('title', 'Análisis de la generación de materiales no fulerenos para el mejoramiento de la eficiencia de paneles solares'))
    doc.preamble.append(Command('author', 'Anonymous author'))
    doc.preamble.append(Command('date', NoEscape(r'\today')))
    doc.append(NoEscape(r'\maketitle'))

    fill_document(doc)

    doc.generate_pdf('artículo', clean_tex=False)
    tex = doc.dumps()  # The document as string in LaTeX syntax

# %% [markdown]
# #Código Molecula

# %% [markdown]
# ##Carga de base de datos principal para moleculas  (molecule)

# %%
#Comma separated value text file containing information on the
#entire dataset of acceptor molecules, 51280 in total

dataOfAceptors = pd.read_csv('/content/drive/My Drive/proyectoSolarCells/mmc2.csv')
dataOfAceptors.head()

# %%
#Comma separated value text file containing information on the 112
#fragments used to build the library of molecules

data3 = pd.read_csv('/content/drive/My Drive/proyectoSolarCells/mmc3.csv')
data3.head()

# %%
#– Comma separated value text file containing information on fingerprint
#analysis utilizing 8192 bits with a connectivity radius of 4.

data4 = pd.read_csv('/content/drive/My Drive/proyectoSolarCells/mmc4.csv')
data4.head()

# %%
#Comma separated value text file containing
#information on molecules used for HOMO-LUMO GP calibration

data5 = pd.read_csv('/content/drive/My Drive/proyectoSolarCells/mmc5.csv')
data5.head()

# %%
#– Comma separated value text file containing information
#on molecules used for PCE GP calibration

data6 = pd.read_csv('/content/drive/My Drive/proyectoSolarCells/mmc6.csv')
data6.head()

# %% [markdown]
# ##Conformers y minimización de energía utilizando el método MMFF, comprobado por los enlaces que se muestran al inicio.

# %%
#función que genera conformers
def gen_conformers(mol, numConfs=100, maxAttempts=1000, pruneRmsThresh=0.1, useExpTorsionAnglePrefs=True, useBasicKnowledge=True, enforceChirality=True):
  ids = AllChem.EmbedMultipleConfs(mol, numConfs=numConfs, maxAttempts=maxAttempts, pruneRmsThresh=pruneRmsThresh, useExpTorsionAnglePrefs=useExpTorsionAnglePrefs, useBasicKnowledge=useBasicKnowledge, enforceChirality=enforceChirality, clearConfs=True, randomSeed=-1, numThreads=0)
  return list(ids)
	
def calc_energy(mol, conformerId, minimizeIts):
  ff = AllChem.MMFFGetMoleculeForceField(mol, AllChem.MMFFGetMoleculeProperties(mol), confId=conformerId)
  ff.Initialize()
  ff.CalcEnergy()
  results = {}
  if minimizeIts > 0:
    results["converged"] = ff.Minimize(maxIts=minimizeIts)
  results["energy_abs"] = ff.CalcEnergy()
  molblock.append(Chem.rdmolfiles.MolToMolBlock(m, confId=conformerId))
  return results


################################################################################
smiles_molecules = dataOfAceptors.smiles
molecule = Chem.MolFromSmiles(smiles_molecules[0])
m = Chem.AddHs(molecule)
numConfs = 10
minimizeIterations = 2000

conformerIds = gen_conformers(m, numConfs=numConfs)
conformerPropsDict = {}
moleculeConf = {}
molblock = []
molblock.append(Chem.rdmolfiles.MolToMolBlock(m))
for conformerId in conformerIds:
  # energy minimise (optional) and energy calculation
  props = calc_energy(m, conformerId, minimizeIterations)
  conformerPropsDict[conformerId+1] = props

# %%
def unique(list1): 
    x = np.array(list1) 
    return(np.unique(x)) 

energy_conformers = []
for conformerId in conformerIds:
  ff = AllChem.MMFFGetMoleculeForceField(m, AllChem.MMFFGetMoleculeProperties(m), confId=conformerId)
  energy_conformers.append(ff.CalcEnergy())

energy_conformers = np.array(energy_conformers)
energy_conformers.min()

# %%
patt = Chem.MolFromSmarts('S1c=cc=c1')
Chem.rdMolAlign.AlignMol(m, patt)
len(unique(energy_conformers))

# %%
conf_id = 1400
ff = AllChem.MMFFGetMoleculeForceField(m, AllChem.MMFFGetMoleculeProperties(m), confId=conf_id)
print(ff.CalcEnergy())
m2 = Chem.MolFromMolBlock(molblock[conf_id+1], removeHs = False)
m2

# %%
patt = Chem.MolFromSmarts('S1c=cc=c1')
patt

# %% [markdown]
# matches = []
# for mol in molblock:
#   m = Chem.MolFromMolBlock(mol, removeHs = False)
#   for mol_match in molblock:
#     if m.HasSubstructMatch(Chem.MolFromMolBlock(mol_match, removeHs = False)):
#       matches.append(mol)
#
# len(matches)

# %%
# !time conda install -q -y -c conda-forge openbabel

# %% [markdown]
# #Pruebas

# %% [markdown]
# ##Confirmación valores MMFF

# %%
#for smiles in smiles_molecules:
m = Chem.MolFromSmiles('CC(C)CN1C(=O)N(C)C(=O)c2[nH]cnc12') # smile obtenido de Structure name: CEWVIJ10 
m = Chem.AddHs(m)
AllChem.EmbedMolecule(m)
ff = AllChem.MMFFOptimizeMoleculeConfs(m, maxIters=10000)
print(ff)
m

# %% [markdown]
# ##Método DFT
